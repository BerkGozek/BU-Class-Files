# %% [markdown]
# Congratulations!  If you're reading this, you've successfully loaded up a Python notebook.  We'll assume you're doing this in Google Colab.  Here is a tour of some Google Colab features.

# %% [markdown]
# Notebook cells come in two flavors:  text boxes and code boxes.  The cell below this one is a code box.  In Google Colab, you can run code boxes by mousing over the [] at the left of the code box, which should turn into an arrow, and then clicking on the arrow.  Try that below.

# %%
2 + 2

# %% [markdown]
# The arrow should turn into a [1] when you mouse elsewhere, indicating it was the first thing you ran.  The order in which you run code can be important.  Try running it again and verify that the [1] becomes a [2].

# %% [markdown]
# You can create your own new text and code boxes.  Try creating one of each below this box with Insert->Text cell and Insert->Code cell.

# %% [markdown]
# Then, delete the new cells by clicking on them, then using the trash can icon at the far right of the box.

# %% [markdown]
# Sometimes, things get confusing - you've run cells in a weird order, or you've changed a cell many times in a way that could have lingering effects, and you just want to start over without having to click on all the arrows individually.  Try "Runtime->Restart and run all" to run all of the code cells in this notebook.

# %%
print('Code cell 1')

# %%
print('Code cell 2')

# %%
print('Code cell 3')

# %% [markdown]
# You can click on the filename at the top to rename the file.  Assignments are generally named 'YourName_RestOfFilename' so that you can replace YourName with your actual name.  This is also a good way to ensure that you don't accidentally submit the starting version of the homework file.
#
# Try renaming the file now.

# %% [markdown]
# To submit a notebook, you'll need to download it first.  Go to File->Download->Download .ipynb and verify that you get the file where you expected it on your machine.

# %% [markdown]
# It's also good to submit a backup PDF in case your original .ipynb is corrupted or the wrong file.  Try downloading this notebook as a PDF with File->Print and selecting "Save as PDF" as the printer.

# %% [markdown]
# A cool aspect of Google Colab notebooks (that we won't take advantage of in this course) is that you can choose to use GPU's (graphical processing units) to speed up AI, machine learning, and other tasks that use linear algebra. You can find the dropdown for this in Edit->Notebook settings.  You may also notice the option to select "TPUs", or Tensor Processing Units, which specifically speed up neural networks.  Just remember this is here when you're doing more advanced projects later in your data science career.

# %% [markdown]
# Occasionally, you may write code that does not know when to quit.  Without intervention, it will run forever.  You can use Runtime->Interrupt execution to get back control.  Try removing the # symbols from the code box below, run it, and then wrest back control with Runtime->Interrupt execution.

# %%
#while(True):
#  print('Hello!')

# %% [markdown]
# You'll notice interrupting the program resulted in an error - a relatively informative error.  It tells you it was a KeyboardInterrupt - you probably didn't use the keyboard to interrupt, but that's the general category of error created when the user interrupts the program.  It has a big arrow pointing to the line with print('Hello!'), indicating that this is what it was doing when it died.
#
# The "Search Stack Overflow" button is also an option, although this is hit or miss in being truly relevant to your crash (the first hit for me here talks about hitting control-C, which could be confusing if you ended the program in Colab like we did).  There's also some junk telling us very exactly what the program was doing when it died - the minutia of printing stuff - which in this case is not that informative.
#
# If you do get errors that look like this, it may take some sleuthing to figure out what the crash is trying to tell you.  Combine the information you can glean from the crash with your own powers of deduction.

# %% [markdown]
# # Decidedly Pro Tip

# %% [markdown]
# As a final step in your Google Colab orientation, go to Tools->Settings->Miscellaneous to turn on a real power user mode.
