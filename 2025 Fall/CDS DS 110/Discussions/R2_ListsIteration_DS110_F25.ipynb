# %% [markdown]
# # Discussion section 2 - Data structures and iteration

# %% [markdown]
# # Problem 1: Term review
#
# Describe the following in a few sentences:
#
# **while loop**
#     a loop that continues to repeat the code inside it until the condition it's given is proven false
#
# **for loop**
#     a loop that repeat the code inside it for a set amount of times.
#
# **Boolean operators**
#     operators that compare 2 booleans(true and false)
# **List**
#     a set of objects that is mutible(changable)
# **Tuple**
#     a set of objects that is immutibale
# **Module**
#     A file in Python that contains code you can import and use in your own programs. Modules let us reuse code instead of rewriting it ourselves.

# %% [markdown]
# # Problem 2: Lists and Tuples
#
# Create a list called my_list of values containing the integers 2-5 and print my_list.

# %%
# TODO
my_list=[2,3,4,5]
print(my_list)
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# Create a a list called my_list2 of values containg the integers 2-5 by using the range function.  (Note that the list() function can turn a generator like range() into a list of what it would generate.)

# %%
# TODO
my_list2=[]
for i in range(2,6):
    my_list2.append(i)
print(my_list2)
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# The `zip(list1, list2)` function takes as input two lists, list1 and list2, and aggregates the elements in these lists into tuples. The function returns an iterable object containing these tuples. To understand this concept run the code below.

# %%
letters = ['a', 'b', 'c', 'd', 'e']
numbers = [1,2,3,4,5]
zipped = zip(letters, numbers)
print(zipped) # an object, not a list zipped[0] will fail
for item in zipped: # we can loop over zipped, that's what being iterable means
    print(item) # each item in zipped is a tuple containing ("a", 1), ("b", 2), etc
# Out:
# ...
# ('a', 1)
# ('b', 2)
# ('c', 3)
# ('d', 4)
# ('e', 5)

# %% [markdown]
# Use `zip` to create the same list of tuples as described above. Store this list in a variable called `my_tuple2` and print this variable to the screen.

# %%
# TODO
my_tuple2 = []
letters = ['a', 'b', 'c', 'd', 'e']
numbers = [1,2,3,4,5]
zipped_2 = zip(letters,numbers)
for i in zipped_2:
    my_tuple2.append(i)
print(my_tuple2)
# Out:
# [('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e', 5)]

# %% [markdown]
# # Problem 3: Loops
#
# Write a loop to deconstruct `my_tuple2` into its original lists. Call these lists `letters2` and `numbers2`.

# %%
# TODO
letters2=[]
numbers2=[]
for item in my_tuple2:
    letters2.append(item[0])
    numbers2.append(item[1])
print(letters2)
print(numbers2)
# Out:
# ['a', 'b', 'c', 'd', 'e']
# [1, 2, 3, 4, 5]

# %% [markdown]
# The `sort()` function of a list `my_list` accepts as input a boolean parameter called *reverse*. The default value of reverse is False (i.e., ascending order). To sort in descending order you set the value of reverse to True. Write code to sort letters2 in reverse alphabetical order and numbers2 in descending order.

# %%
# TODO
letters2.sort(reverse=True)
numbers2.sort(reverse=True); 
print(letters2)
print(numbers2)
# Out:
# ['e', 'd', 'c', 'b', 'a']
# [5, 4, 3, 2, 1]

# %% [markdown]
# # Problem 4: Boolean operators
#
# Explain the behavior when debt = 500, defaults == 0, and blacklisted = True.  Then describe in words what the general policy is for deciding whether to print "Approved".

# %%
debt = 500
defaults = 0
blacklisted = True

if (debt < 10000 or defaults == 0) and not blacklisted:
    print("Approved")
else:
    print("Denied")
# Out:
# Denied

# %% [markdown]
# Iterate through the following list of tuples to find and print the worst movie (movie with the lowest second element).

# %%
movies = [('Plan 9 from Outer Space', 2),
          ('Cats', 1.5),
          ('The Matrix Reloaded', 2),
          ('The Fifth Element', 2.5)]

worst_movie = 'none'
worst_rating = 6
    

# TODO
for i in movies:
    if(worst_rating>i[1]):
        worst_rating = i[1]
        worst_movie = i[0]

print(worst_movie)
# Out:
# Cats

# %% [markdown]
# # Problem 5: Some important Python modules

# %% [markdown]
# ## Math
#
# Write a loop that iterates through a list and prints every other item, starting with printing the 0th item.  (Hint:  If the index is divided by 2, the remainder should be 0 to print.)  You may need to look up what the math module can do to find an appropriate function.

# %%
import math
a = ["foo", "bar", "baz", "qux"]
# TODO
for i in range(len(a)):
    if(i%2==0):
        print(a[i])
# Out:
# foo
# baz

# %% [markdown]
# Iterate through the list of floats and create a new list containing the floor of each floating point number.

# %%
numbers = [1.1, 3.2, 4.9, 20.2, 100.7]
floored_numbers = []
# TODO
for i in numbers:
    floored_numbers.append(i//1)
# Out:
# [1.0, 3.0, 4.0, 20.0, 100.0]

# %% [markdown]
# ## Time
#
# Complete the below code to time how long the below summation loop takes.  (Again, look up what you can do with the time module.)

# %%
import time

start_time = time.time()# TODO 


iterations = 1000000
sum = 0
for i in range(iterations):
    sum += 1

end_time = time.time()# TODO

elapsed_time = end_time - start_time

print(f"Elapsed time for {iterations} iterations: {elapsed_time:.6f} seconds")
# Out:
# Elapsed time for 1000000 iterations: 0.076574 seconds

# %% [markdown]
# ## String
#
# Execute the following code. What is the return type of these constants?
#
# **Answer: TODO**

# %%
import string

letters = string.ascii_letters
uc_letters = string.ascii_uppercase
print(letters)
print(uc_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %% [markdown]
# Write code that stores the output of `string.digits` into a variable called digits. What is the type of digits?
#
# **Answer:  TODO**

# %%
# TODO
digits = string.digits
#the digits variable is a string
# Out:
# <class 'str'>

# %% [markdown]
# The string method call `.count('the')` counts how many times a string contains the substring *the*. Given the following text as a string, count how many times the substring *oses* occurs in the string below.

# %%
text = """Moses supposes his toeses are roses,
but Moses supposes erroneously.
For Moses he knowses his toeses aren't roses
as Moses supposes his toeses to be.
"""

# %%
# TODO
print(text.count("oses"))
# Out:
# 9
