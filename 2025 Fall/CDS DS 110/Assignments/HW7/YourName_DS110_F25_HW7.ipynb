# %% [markdown]
# # HW7 (72 points)

# %% [markdown]
# # Problem 1:  Recursion on Trinary Trees (20 points  [10, 10])

# %%
class TrinaryTree():
    def __init__(self, left, middle, right, value):
        self.value = value
        self.left = left
        self.middle = middle
        self.right = right

# %% [markdown]
# a, 10 points) Write a *recursive* function `tree_min()` that takes as an argument a trinary tree such as the one defined above, and returns the min of all the values in the tree.  If there are no items in the tree (it is None), return None.

# %%
#TODO
def tree_min(tree : TrinaryTree):

# %%
tree1 = TrinaryTree(
    TrinaryTree(None, None, None, 5),
    TrinaryTree(None, None, None, 3),
    TrinaryTree(None, None, None, 8),
    10
)
print(tree_min(tree1))  # Expect 3

tree2 = None
print(tree_min(tree2))  # Expect None

# %% [markdown]
# b, 10 points) Write a function count_unbalanced() that takes a trinary tree and *recursively* counts the number of nodes that do not possess all three nodes - for example, only a left node or a left and right node but no middle node.  Assume the tree argument was created using the provided trinary tree class.  A missing child is signified by a left, middle, or right field that is None.  (The value field is not useful for this exercise.)

# %%
#TODO

# %% [markdown]
# # Problem 2:  Nearest neighbors (24 points [1,2,3,4,3,6,5])

# %% [markdown]
# In this problem, we'll train on the wines dataset (https://archive.ics.uci.edu/dataset/109/wine).

# %%
from sklearn.datasets import load_wine

# Load the dataset
data = load_wine(as_frame=True)
X = data.data
y = data.target

X.head()

# %% [markdown]
# a, 1 pts) Print the column (feature) names of the dataframe X.

# %%
#TODO

# %% [markdown]
# b, 2 pts) Using the method `value_counts()` on the target variable `y` determine the number of targets within each distinct target class.

# %%
#TODO

# %% [markdown]
# c, 3 pts) Now use scikit-learn's train_test_split() function to separate X and y into training and test sets. Pass in the argument random_state=110 and use a test size of 0.2 so that your split is consistent with other students' and ours.

# %%
#TODO

# %% [markdown]
# d, 4 pts) Train a k-nearest neighbors classifier on the training data, where k is 3.

# %%
#TODO

# %% [markdown]
# e, 3 pts) Use the score() method of the nearest neighbors classifier on the test data, to determine how well this classifier does on the withheld data.

# %%
#TODO

# %% [markdown]
# f, 6 pts) This accuracy seems low. Look at your dataset and implement a solution which improves the accuracy. Do not adjust the number of neighbors k, the seed or the test_size in the train_test_split method. Retrain this new model and report the accuracy.

# %%
#TODO

# %% [markdown]
# g, 5 pts) Does using the score() method with your k=3 model on the training data give 100% accuracy? For which value of k would you expect a KNN model to give 100% accuracy on the training data and why?

# %%
#TODO

# %% [markdown]
# **Answer:**

# %% [markdown]
# # Problem 3:  Decision trees (26 points [8,4,6,4,4])

# %% [markdown]
# a, 8 pts) Reload the original wine data set and create the same train/test split as the previous problem, train a scikit-learn entropy-based decision tree classifier on the unscaled data, and use score() to evaluate the classifier. When creating the DecisionTreeClassifier (anytime throughout problem 3), pass in the argument random_state=110 so its behavior matches our solution.

# %%
#TODO

# %% [markdown]
# b, 4 pts) Is it a necessary step to scale your input data prior to training with a decision tree model?

# %% [markdown]
# **Answer: It is not necessary because the splitting of the data within a decision tree model uses thresholds and not distances or magnitudes.**

# %% [markdown]
# c, 6 pts) What is overfitting?  (If you use language from another source to answer this, cite the source.)  Call score() on the training data.  Is this performance consistent with the idea that the model is overfitting?

# %%
#TODO

# %% [markdown]
# **Answer:**

# %% [markdown]
# d, 4 points) Experiment with setting the following parameters of the DecisionTreeClassifier constructor:  max_depth=2, min_samples_leaf=4, random_state=110.  Does the evidence from train and test performance suggest the model is overfitting now?

# %%
#TODO

# %% [markdown]
# **Answer:**

# %% [markdown]
# e, 4 points) Using tree.plot_tree(), draw the tree you made in part (c).  You don't need to name the types or features.

# %%
#TODO

# %% [markdown]
# # AI Statement (2 points)
#
# Please put an X in the box that best matches your AI use for this homework ([X] in the markup will become a checked box).  There is no penalty for using AI, but we want to understand how you're using it.
#
# - [ ] I did not use AI to complete this assignment.
# - [ ] I didn't use AI to debug or generate code, but I did use it as a Python reference.
# - [ ] I didn't use AI to generate code, but I did use it to debug some code.
# - [ ] I did use AI to generate some code, but not all the code for any problem.
# - [ ] I used AI to solve at least one problem completely.

# %% [markdown]
# **When you are done, submit both your .ipynb (File->Download->Download .ipynb in Google Colab) and a PDF (File->Print->Save to PDF) to Blackboard where you found this assignment.**  (The backup PDF helps us give you points if there's a problem with your .ipynb.)
