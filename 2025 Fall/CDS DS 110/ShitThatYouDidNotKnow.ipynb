# %% [markdown]
# Edge/Corner Case: A case where all compared values are the same (more than 2 values are compared in an if case in different if/elif statements)

# %%
#this is xor, written with ^ (shift+6)
print(False^True)
print(False^False)
print(True^True)
# Out:
# True
# False
# False

# %%
#string.isdigit()

print("0".isdigit())
# Out:
# True

# %%
import numpy as np
print(np.zeros((2, 3)))
print(np.ones((3, 3)))
(np.arange(0, 10, 2))
print(np.linspace(0, 1, 5))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])
